# %%
pip install nilearn scikit-learn pandas numpy matplotlib seaborn
# Out:
# ...
#
# ...
#    ---------------------------------------- 0.0/10.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.6 MB ? eta -:--:--
#    - -------------------------------------- 0.5/10.6 MB 1.9 MB/s eta 0:00:06
#    --- ------------------------------------ 1.0/10.6 MB 2.4 MB/s eta 0:00:04
#    ---- ----------------------------------- 1.3/10.6 MB 2.5 MB/s eta 0:00:04
#    ------ --------------------------------- 1.8/10.6 MB 1.9 MB/s eta 0:00:05
#    ------- -------------------------------- 2.1/10.6 MB 1.8 MB/s eta 0:00:05
#    --------- ------------------------------ 2.6/10.6 MB 2.0 MB/s eta 0:00:04
#    ----------- ---------------------------- 3.1/10.6 MB 2.1 MB/s eta 0:00:04
#    ------------ --------------------------- 3.4/10.6 MB 1.9 MB/s eta 0:00:04
#    -------------- ------------------------- 3.9/10.6 MB 2.0 MB/s eta 0:00:04
#    ---------------- ----------------------- 4.5/10.6 MB 2.0 MB/s eta 0:00:04
# ...

# %%
import pandas as pd
import numpy as np
from nilearn import datasets
from nilearn.connectome import ConnectivityMeasure

print("Conectando con el repositorio ABIDE y descargando datos históricos...")

# 1. Descargamos los datos fenotípicos (edad, sexo, diagnóstico, etc.) y las series temporales
# Usamos el atlas 'craddock_2012' y la estrategia de preprocesamiento 'cpac'
data_triplet = datasets.fetch_abide_pcp(
    n_subjects=40,            # Empezamos con un piloto de 40 pacientes para probar el flujo rápido
    pipeline="cpac",
    data_type="rois",         # Descargamos por Regiones de Interés (ROIs) para tener matrices numéricas directo
    quality_checked=True      # Solo pacientes que pasaron el control de calidad médico
)
# Out:
# Conectando con el repositorio ABIDE y descargando datos históricos...
# [fetch_abide_pcp] Dataset found in C:\Users\luna_\nilearn_data\ABIDE_pcp
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'data_type'
#
# The above exception was the direct cause of the following exception:
#
# ...
